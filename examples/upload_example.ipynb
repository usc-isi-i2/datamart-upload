# %%
from datamart_isi.upload.store import Datamart_isi_upload
# this sample will save the following online csv datasets into datamart in blaze graph
a = Datamart_isi_upload()
# Out:
# d3m.primitives.data_cleaning.cleaning_featurizer.DSBOX: Primitive is not providing a description through its docstring.
# d3m.primitives.data_cleaning.column_fold.DSBOX: Primitive is not providing a description through its docstring.
# warn from part 4 d3m.primitives.data_cleaning.labeler.DSBOX

# %%
# check which number will be the next datamart id
a.resource_id
# Out:
# 1000031

# %%
# test uploading with online csv format data
all_dir = ["https://raw.githubusercontent.com/usc-isi-i2/datamart-userend/master/example_datasets/List_of_United_States_counties_by_per_capita_income.csv", 
    "https://raw.githubusercontent.com/usc-isi-i2/datamart-userend/master/example_datasets/Most-Recent-Cohorts-Scorecard-Elements.csv", 
    "https://raw.githubusercontent.com/usc-isi-i2/datamart-userend/master/example_datasets/Unemployment.csv", 
    "https://raw.githubusercontent.com/usc-isi-i2/datamart-userend/master/example_datasets/educate.csv", 
    "https://raw.githubusercontent.com/usc-isi-i2/datamart-userend/master/example_datasets/population.csv", 
    "https://raw.githubusercontent.com/usc-isi-i2/datamart-userend/master/example_datasets/poverty.csv"
    ]

# %%
# load one example
dfs, metas=a.load_and_preprocess(input_dir=all_dir[0],file_type="online_csv")
# Out:
# Current column: Rank
# A columns with all numerical values and useless detected, skipped
# Current column: County-area
# The best matching P node is P428
# [WARNING] Coverage of Q nodes is 0.3623926185173401 which is less than threshold 0.7
# Current column: State
# The best matching P node is P2390
# Current column: Per capita income
# [ERROR] No candidate P nodes found for input column : [Per capita income]
# Current column: Median household income
# [ERROR] No candidate P nodes found for input column : [Median household income]
# Current column: Median family income
# [ERROR] No candidate P nodes found for input column : [Median family income]
# Current column: Population
# The best matching P node is P1422
# [WARNING] Coverage of Q nodes is 0.011135857461024499 which is less than threshold 0.7
# Current column: Number of households
# The best matching P node is P6103
# [WARNING] Coverage of Q nodes is 0.03881641743557111 which is less than threshold 0.7
# ...

# %%
# dfs is a list of dataframes, here we upload online so it will only have one dataframe
dfs[0].head()
# Out:
#    Rank        County-area       State Per capita income  \
# 0     1    New York County    New York          $62,498
# 1     2          Arlington    Virginia          $62,018
# 2     3  Falls Church City    Virginia          $59,088
# 3     4              Marin  California          $56,791
# 4     5    Alexandria City    Virginia          $54,608
#
#   Median household income Median family income Population  \
# 0                $69,659              $84,627   1,605,272
# 1               $103,208             $139,244     214,861
# 2               $120,000             $152,857      12,731
# 3                $90,839             $117,357     254,643
# 4                $85,706             $107,511     143,684
#
#   Number of households                             County-equivalent_link  \
# 0              736,192            https://en.wikipedia.org/wiki/Manhattan
# 1               94,454  https://en.wikipedia.org/wiki/Arlington_County...
# ...

# %%
metas[0]
# Out:
# {'datamart_id': None,
#  'materialization': {'python_path': 'default_materializer', 'arguments': None},
#  'variables': [{'datamart_id': None,
#    'semantic_type': ['https://metadata.datadrivendiscovery.org/types/Attribute',
#     'http://schema.org/Integer'],
#    'name': 'Rank',
#    'description': 'column name: Rank, dtype: int64'},
#   {'datamart_id': None,
#    'semantic_type': ['https://metadata.datadrivendiscovery.org/types/Attribute',
#     'http://schema.org/Text'],
#    'name': 'County-area',
#    'description': 'column name: County-area, dtype: object',
#    'named_entity': ['New York County',
#     'Arlington',
#     'Falls Church City',
#     'Marin',
#     'Alexandria City',
#     'Pitkin',
#     'Los Alamos',
#     'Fairfax County',
#     'Hunterdon',
#     'Borden',
#     'Montgomery',
#     'Morris',
#     'Fairfield',
#     'San Francisco',
#     'Howard',
#     'Westchester',
#     'Somerset',
#     'Nantucket',
#     'Loudoun',
#     'North Slope',
# ...

# %%
# same as mentioned, only 1 meta information corresponding to dfs[0]
metas[0].keys()
# Out:
# dict_keys(['datamart_id', 'materialization', 'variables', 'title', 'description', 'keywords', 'url', 'file_type'])

# %%
# if you want to change title, description or keywords by yourself, just change like this
metas[0]['title'] = "your title want to change"
metas[0]['description'] = "your description want to change"
metas[0]['keywords'] = ['your', 'keywords', 'want to', 'change']
# then you can upload this, here this 0 means which number of the generated df and corresponding meta you want to model
a.model_data(dfs, metas, 0)
# every time after you model one dataframe, you have to run upload first before model next one
a.upload()
# Out:
# Upload file finished with status code: 200!
# /Users/minazuki/miniconda3/envs/datamart/lib/python3.6/site-packages/SPARQLWrapper/Wrapper.py:709: UserWarning: keepalive support not available, so the execution of this method has no effect
#   warnings.warn("keepalive support not available, so the execution of this method has no effect")
# Update truthy finished!

# %%
# upload remained automatically
for each_dir in all_dir[1:]:
    dfs, metas=a.load_and_preprocess(input_dir=each_dir,file_type="online_csv")
    # there should only have one table extracted from one online csv address
    a.model_data(dfs, metas, 0)
    a.upload()
# Out:
# Current column: UNITID
# The best matching P node is P698
# Current column: OPEID
# The best matching P node is P932
# [WARNING] Coverage of Q nodes is 0.6839024390243903 which is less than threshold 0.7
# Current column: OPEID6
# The best matching P node is P359
# Current column: INSTNM
# The best matching P node is P3482
# [WARNING] Coverage of Q nodes is 0.00013937282229965157 which is less than threshold 0.7
# Current column: CITY
# The best matching P node is P428
# [WARNING] Coverage of Q nodes is 0.12320557491289198 which is less than threshold 0.7
# Current column: STABBR
# The best matching P node is P5086
# Current column: INSTURL
# [ERROR] No candidate P nodes found for input column : [INSTURL]
# Current column: NPCURL
# [ERROR] No candidate P nodes found for input column : [NPCURL]
# Current column: HCM2
# A columns with all numerical values and useless detected, skipped
# Current column: PREDDEG
# A columns with all numerical values and useless detected, skipped
# ...

# %%
# test uploading with wikipedia table type
all_dir_wikipedia_test = ["https://en.wikipedia.org/wiki/1962_Washington_Senators_season", "https://en.wikipedia.org/wiki/2017%E2%80%9318_New_Orleans_Privateers_women%27s_basketball_team", "https://en.wikipedia.org/wiki/List_of_Asian_Games_medalists_in_cue_sports"]

for input_dir in all_dir_wikipedia_test:
    dfs ,metas=a.load_and_preprocess(input_dir=input_dir,file_type="wikitable")
    # here because wikipedia page may have multiple tables in one page, we will add the value i to let the system know which you want to upload
    for i in range(len(dfs)):
        a.model_data(dfs, metas, i)
        a.upload()
# Out:
# Current column: American League
# [ERROR] No candidate P nodes found for input column : [American League]
# Current column: attribute_0
# The best matching P node is P2898
# [WARNING] Coverage of Q nodes is 0.5 which is less than threshold 0.7
# Current column: attribute_1
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.425 which is less than threshold 0.7
# Current column: Team
# The best matching P node is P3417
# [WARNING] Coverage of Q nodes is 0.3 which is less than threshold 0.7
# Current column: attribute_0
# The best matching P node is P5696
# [WARNING] Coverage of Q nodes is 0.5 which is less than threshold 0.7
# Current column: attribute_1
# The best matching P node is P721
# [WARNING] Coverage of Q nodes is 0.1 which is less than threshold 0.7
# Current column: Pos
# The best matching P node is P5987
# Current column: Player
# [ERROR] No candidate P nodes found for input column : [Player]
# Current column: G
# ...
